# %% [markdown]
# # HW1
# ### Pavel_Belov

# %% [markdown]
# ## Задание 1
#
# $7\cdot\begin{bmatrix}5 & 10 \\7 & 12 \\ 11.3 & 5 \\ 25 & 30 \end{bmatrix} + 2\cdot\begin{bmatrix}5 & 10 \\7 & 12 \\ 11.3 & 5 \\ 25 & 30 \end{bmatrix} = 9\cdot\begin{bmatrix}5 & 10 \\7 & 12 \\ 11.3 & 5 \\ 25 & 30 \end{bmatrix} = \begin{bmatrix}45 & 90 \\63 & 108 \\ 101.7 & 45 \\ 225 & 270 \end{bmatrix}$

# %% [markdown]
# //a + b = c

# %% [markdown]
# ### Задание 2.1

# %% [markdown]
# \begin{cases}3 x -2 y +5 z =7 \\ 7 x +4 y -8 z =3  \\ 5 x -3 y -4 z = -12\end{cases}
#
# \begin{cases}3 x -2 y +5 z =7 \\ 7 x +4 y -8 z =3  \\ -10x +6 y +8 z = 24\end{cases}
#
# \begin{cases}3 x -2 y +5 z =7 \\ -3 x +10 y = 27  \\ 8 y +5 z = 34\end{cases}
#
# \begin{cases}y = 0.3 x + 2.7 \\ z = (8.2 x + 10.8) / 8  \\ 3 x -2 ( 0.3 x + 2.7) +5 ((8.2 x + 10.8) / 8) =7 \end{cases}
#
# \begin{cases}x = 1 \\ y = 3 \\ z = 2  \end{cases}

# %% [markdown]
# ## Задание 2.2

# %% [markdown]
# \begin{cases}x ^ 2 + y * x - 9 = 0 \\ x - \frac{y}{5} = 0\end{cases}
# \begin{cases}y = 5 x \\ x ^ 2 + 5 x ^ 2 - 9 = 0\end{cases}
# \begin{cases} 6  x ^ 2  = 9 \\ y = 5 x\end{cases}
# \begin{cases}x_1 = \sqrt{1.5} & x_2 = -\sqrt{-1.5} \\ y_1 = 5\sqrt{1.5} & y_2 = -5 \sqrt{-1.5} \end{cases}

# %% [markdown]
# ## Задание 3
#
# #### Решите задачу:
# Площадь пола прямоугольной комнаты равна 48 м2,а его периметр равен 28 м. Найдите длину и ширину комнаты.

# %% [markdown]
# \begin{cases}a * b = 48 \\ a + b = \frac{28}{2}\end{cases}
#
# \begin{cases}a = 14 - b \\b^2 + 14b - 48 = 0 \end{cases}
#
# Найдем возможные стороны.
#
# $$D = 14^2 - 4 * 48 = 4$$
#
# $$b_1 = 6$$
#
# $$b_2 = 8$$
#
# $$a_1 = 8$$
# $$a_2 = 6$$
#
# Ответ: Стороны прямоугольника равняются 6 и 8.

# %% [markdown]
# ## Задание:
# Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# %%
X = np.linspace(0, 2*pi, 101)
K = np.linspace(0, 2*pi, 101)
plt.plot(X, np.cos(X), marker="o")
plt.plot(K, np.cos(1.2*K), marker="x");
